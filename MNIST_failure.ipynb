# %% [markdown]
# <a href="https://colab.research.google.com/github/itsautfullday/FastAI/blob/master/MNIST_failure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
from pathlib import Path

# %%
path = untar_data(URLs.MNIST)

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_png/testing'),
#  PosixPath('/root/.fastai/data/mnist_png/training')]

# %%
train_folder = path/'training'
test_folder = path/'testing'

# %%
# !cd {train_folder}

# %%
cd ..
# Out:
# /

# %%
path
# Out:
# PosixPath('/root/.fastai/data/mnist_png')

# %%
train_folder.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_png/training/7'),
#  PosixPath('/root/.fastai/data/mnist_png/training/5'),
#  PosixPath('/root/.fastai/data/mnist_png/training/2'),
#  PosixPath('/root/.fastai/data/mnist_png/training/3'),
#  PosixPath('/root/.fastai/data/mnist_png/training/0'),
#  PosixPath('/root/.fastai/data/mnist_png/training/9'),
#  PosixPath('/root/.fastai/data/mnist_png/training/6'),
#  PosixPath('/root/.fastai/data/mnist_png/training/1'),
#  PosixPath('/root/.fastai/data/mnist_png/training/4'),
#  PosixPath('/root/.fastai/data/mnist_png/training/8')]

# %%
data = ImageDataBunch.from_folder(path,train = 'training',test = 'testing',valid_pct= 0.2)

# %%
data.show_batch()

# %%
model = cnn_learner(data,models.resnet50,  metrics = error_rate)

# %%
model.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.615632</td>
#       <td>0.402997</td>
#       <td>0.128250</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.235515</td>
#       <td>0.144119</td>
#       <td>0.045667</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.123351</td>
#       <td>0.093310</td>
#       <td>0.030750</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.103019</td>
#       <td>0.083478</td>
#       <td>0.028750</td>
#       <td>00:43</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.save('stage-1')

# %%
model.unfreeze() # no idea what the function does

# %%
model.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
model.recorder.plot()

# %%
model.fit_one_cycle(2, max_lr = slice(5e-6,1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.052235</td>
#       <td>0.051650</td>
#       <td>0.015917</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.041895</td>
#       <td>0.046790</td>
#       <td>0.015083</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.export()

# %%
model.export()

# %%
# Out:
# PosixPath('/root/.fastai/data/mnist_png')

# %%
cd path
# Out:
# [Errno 2] No such file or directory: 'path'
# /content

# %%
cd {path}
# Out:
# /root/.fastai/data/mnist_png

# %%
ls
# Out:
# export.pkl  models/  testing/  training/

# %%
defaults.device = torch.device('cpu')
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_png/testing'),
#  PosixPath('/root/.fastai/data/mnist_png/export.pkl'),
#  PosixPath('/root/.fastai/data/mnist_png/models'),
#  PosixPath('/root/.fastai/data/mnist_png/training')]

# %%
learner = load_learner(path)

# %%
img = open_image('N7.jpg')

# %%
img
# Out:
# Image (3, 1280, 720)

# %%
pred_class,pred_idx,outputs = learner.predict(img)

# %%
pred_class
# Out:
# Category 0
